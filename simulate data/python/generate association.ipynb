# %%
import numpy as np
import pickle
import os
import pandas as pds
import datetime

# %%
name_DF = 'DF_N=76_2023-01-04.csv'
DF = pds.read_csv(os.path.join('..', 'datasets', name_DF), delimiter = ',')
DF = DF[~DF.duplicated()] # delete duplicates
DF = DF.dropna() # delete NaN in names
DF
# Out:
#          name family name gender country  birth year
# 0    Natascha       Blvck      F      AT        2004
# 1    Wilfried     Giebens      M      BE        2019
# 3    Caroline      Mendez      F      FR        1964
# 4      Maithe     Chapuis      F      FR        1979
# 5      Magali    Hyvernat      F      FR        1979
# ..        ...         ...    ...     ...         ...
# 71  Claudette   Hendricks      F      GB        1989
# 72    Melanie    Sinclair      F      GB        1989
# 73      David    Le Guern      M      GB        2000
# 74      Edgar       Edgar      M      GB        2016
# 75       Paul       Lucas      M      GB        1989
#
# [73 rows x 5 columns]

# %%
with open(os.path.join('..', 'dictionaries', 'country_proba_names_75names.pkl'), 'rb') as f:
    country_proba_names = pickle.load(f)

# %%
# generate treatment
DF['treatment'] = np.random.binomial(n = 1, p = 0.4, size = DF.shape[0])

# generate covariates
DF['X1'] = 2020 - DF['birth year'] # age
DF['X2'] = np.random.normal(loc = np.random.randint(1,11), scale = np.random.uniform(0,2), size = DF.shape[0])
DF['X3'] = np.random.normal(loc = np.random.randint(1,11), scale = np.random.uniform(0,2), size = DF.shape[0])
DF['X4'] = np.random.normal(loc = np.random.randint(5,11), scale = np.random.uniform(0,0.5), size = DF.shape[0])
DF['X5'] = np.random.normal(loc = np.random.randint(1,11), scale = np.random.uniform(0,2), size = DF.shape[0])

# generate outcome
residual_errors = np.random.normal(size = DF.shape[0])
a = np.random.randint(1,21)/10
b = np.random.randint(1,31)/10
c = np.random.randint(1,41)/10
d = np.random.randint(1,11)/10
DF['Y'] = - 10 + a*DF['treatment']*DF['X1'] + b*np.log(DF['X4']) + c*DF['X3']*DF['X2'] + d*DF['X5']

# ATE: a * Expectation(X1)

# %%
DF
# Out:
#          name family name gender country  birth year  treatment  X1        X2  \
# 0    Natascha       Blvck      F      AT        2004          1  16  2.637364
# 1    Wilfried     Giebens      M      BE        2019          0   1  0.747414
# 3    Caroline      Mendez      F      FR        1964          0  56  2.977431
# 4      Maithe     Chapuis      F      FR        1979          1  41  2.366253
# 5      Magali    Hyvernat      F      FR        1979          1  41  0.718582
# ..        ...         ...    ...     ...         ...        ...  ..       ...
# 71  Claudette   Hendricks      F      GB        1989          0  31  1.759580
# 72    Melanie    Sinclair      F      GB        1989          0  31  3.101000
# 73      David    Le Guern      M      GB        2000          0  20  1.608083
# 74      Edgar       Edgar      M      GB        2016          0   4  2.087475
# 75       Paul       Lucas      M      GB        1989          1  31  1.532940
#
#           X3        X4        X5          Y
# 0   8.447581  8.848844  7.096587  16.186727
# 1   8.062860  8.832788  6.551905  -3.329415
# 3   6.044183  8.813380  8.445199   4.419380
# 4   6.644549  8.756793  8.519126  27.674261
# 5   7.402063  8.934581  5.293264  20.474336
# ..       ...       ...       ...        ...
# 71  6.464925  9.055759  7.690786   0.234268
# 72  6.687243  8.931111  8.169161   5.987803
# 73  8.896713  9.105765  7.752153   2.014092
# 74  6.997071  8.963097  8.932578   2.540057
# 75  8.475980  9.194168  5.920312  19.281281
#
# [73 rows x 12 columns]

# %%
DF.to_csv(os.path.join('..', 'datasets', f'DF_associations_N={DF.shape[0]}_{datetime.date.today()}.csv'), index = False)
